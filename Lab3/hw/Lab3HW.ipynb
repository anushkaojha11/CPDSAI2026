# %% [markdown]
# ### **Lab3HW2: Web Scraping a Table** (10 Marks)
#
# **Objective:** Practice the skills of web scraping to extract structured data from a table on a website of your choice.
# You can use either the **Beautiful Soup** or **Selenium** library for this task.
#
# **Goal:** Select a public website, find a table, and extract its data into a pandas DataFrame.
#
# **Instructions:**
#
# 1.  **Choose a Website:** Find a website that has a table with data you find interesting. A good source might be a sports statistics page, a financial data site, or a Wikipedia page.
# 2. **CODE**
# 3.  **Display the Results:** Print the final DataFrame to show the extracted data in a clean, readable format.
#
# Note: You cannot reuse the websites that we learn in the lab session.

# %% [markdown]
# #### **Your Code Here**
