# %% [markdown]
# # Homework: Data Wrangling with Olist E-Commerce Dataset
#
# **Dataset:** Brazilian E-Commerce (Olist)
#
# This homework applies everything covered in Week 4's lab (Series/DataFrame basics, cleaning, groupby, merging, visualization) to a new dataset.
#
# Download the dataset files and place them in a folder called **datasets/** in your homework folder.
#
# Link:
#
# https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce

# %% [markdown]
# ## Task 1: Load the Libraries (0.5 mark)

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Task 2: Load the Datasets (0.5 marks)
#
# Load the following files into DataFrames:
# - `olist_customers_dataset.csv`
# - `olist_order_items_dataset.csv`
# - `olist_order_payments_dataset.csv`
# - `olist_order_reviews_dataset.csv`
# - `olist_orders_dataset.csv`

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Task 3: Data Cleaning (2 Marks)
#
# ### 3.1: Drop Duplicate Rows (1 Mark)
#
# Check for and remove duplicate rows in `customers`, `order_items`, `order_payments`, and `order_reviews`. Print the row count before and after for each, so you can confirm the drop worked.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3.2: Convert Timestamps (1 Mark)
#
# The `orders` dataset has an `order_purchase_timestamp` column stored as text. Check its current data type, then convert it to a proper datetime column, and confirm the change.
#
# **HINT:** use `pd.to_datetime()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Task 4: Exploratory Data Analysis & Visualization (2 Marks)
#
# ### 4.1: Top 10 Payment Types by Number of Orders (1 Mark)
#
# Using `order_payments`, find how many unique orders exist for each `payment_type`, then plot the top 10 as a bar chart.
#
# **HINT:** use `.groupby()` with `.nunique()` on `order_id`, then `.sort_values()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 4.2: Top 10 Product Categories by Number of Orders (1 Mark)
#
# The product category names in `olist_products_dataset.csv` are in Portuguese. You'll need to translate them using `product_category_name_translation.csv`, then connect that to order data.
#
# **HINT:** you'll need to merge three DataFrames step by step:
# 1. `product_category_name_translation` + `olist_products_dataset` (on `product_category_name`)
# 2. Result + `order_items` (on `product_id`)
#
# Then group by the English category name and count unique orders, and plot the top 10.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Task 5: Solve the Use Cases (Total: 5 Marks)
#
# ### 5.1: Top 10 Product Categories by Review Score (2.5 Marks)
#
# **Task:** Find the 10 product categories with the highest average `review_score`, sorted from highest to lowest.
#
# **HINT:** merge your Task 4.2 result with `order_reviews` (on `order_id`), then group by category and take the mean review score.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 5.2: Top 5 Cities for Electronics Sales (2.5 Marks)
#
# **Task:** For the product category `"electronics"`, find the top 5 cities where the product sold the most, based on the **total order price**.
#
# **Assumption:** total order price = `price` + `freight_value`
#
# **HINT:** you'll need to chain several merges to connect product category → orders → customers (for city info). Steps to think through:
# 1. Merge your category+order_items data with `orders` (on `order_id`) to get `customer_id`
# 2. Merge that with `customers` (on `customer_id`) to get `customer_city`
# 3. Create a new column for total order price
# 4. Filter to just the `"electronics"` category
# 5. Group by city, sum the total order price, and sort to find the top 5

# %%
# YOUR CODE HERE
