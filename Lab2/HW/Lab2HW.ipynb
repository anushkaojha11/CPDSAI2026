# %% [markdown]
# ## Homework Name: Lab2HW

# %% [markdown]
# **1 Composite Masking (5 Marks)**
#
# **Task:**
#
# You will create a composite mask by combining three separate conditions on the satellite image's Red, Green, and Blue color layers.
#
# 1. Create a mask where the Red layer's pixel values are greater than 150.
# 2. Create a second mask where the Green layer's pixel values are less than 100.
# 3. Create a third mask where the Blue layer's pixel values are greater than 100.
# 4. Then, combine these three masks using a logical operator to create a final, composite mask.
# 5. Set all pixels not meeting the composite mask condition to black.
# 6. Show the final masked image
#
# **HINT:**
# masked_image[composite_mask] = [0, 0, 0] #This makes all pixels meeting the composite_mask condition to be set to black.
#
# You can use "~" to make all pixels not meeting the composite_mask condition to be set to black.
# i.e. masked_image[~composite_mask] = [0, 0, 0]

# %%
# Create individual masks
red_layer_mask = # To code here
green_layer_mask = # To code here
blue_layer_mask = # To code here

# Combine the masks using a logical AND operator (e.g. a & b & c)
composite_mask = # To code here

# Apply the composite mask to the original image and set pixels not meeting the condition to black. (remember to use "~" which represents "not")
masked_image = image.copy()
# masked_image[~composite_mask] = 

# To code here
# Set pixels not meeting the condition to black

# Display the masked image
# To code here

# %% [markdown]
# **Expected Output:**
# ![Expected Output](composite.png)

# %% [markdown]
# **2 Horizontal Image Flip (5 Marks)**
#
# **Task:**
#
# Flip the original satellite image horizontally.
# This can be done using the `flip` function from numpy but for this homework, do without the help of this function.
#
# 1. Create a flipped image using Slice reversing
# 2. Print the image
#
# **Hint: Reversing the image slice**

# %%
# Make a copy of the original image to manipulate
manipulated_image = image.copy()

# Your code here to create the flipped image
# flipped_photo_data =  manipulated_image[::]

# Print the flipped image
plt.imshow(flipped_image)
plt.title('Flipped Image')
plt.show()

# %% [markdown]
# **Expected Output:**
# ![Expected Output](flipped.png)

# %% [markdown]
# **3 Image Crop (5 Marks)**
#
# **Task:**
#
# Crop the original image to the black rectangle shape below
# Height: 500 - 1,500
# Width: 2,200 - 3,300

# %% [markdown]
# **Crop around the rectangle:**
# ![Expected Crop](crop.jpg)

# %%
# Print original image
plt.imshow(image)

# %%
# Your code here
# Crop the image
# cropped_image = image[:, :]

# %%
# Print the cropped image
plt.imshow(cropped_image)
plt.title('Cropped Image')
plt.show()

# %% [markdown]
# **4 Censor your own portrait image by adding the Black line (5 Marks)**
# • Bar over your eyes using NumPy.
# • Do not use other libraries except NumPy, Matplotlib, and ImageIO
# • Example: https://commons.wikimedia.org/wiki/File:Anon-Black-Bands-Eyes.jpg

# %%
# Your code here
