# %% [markdown]
# ## Telco Customer Churn Dataset (30 points)
#
# This dataset contains customer information from a telecommunications company, including account details, subscribed services, billing information, and whether the customer churned (left the company).
#
# ### __Variable description__
#
# * customerID: Unique identifier for each customer
# * gender: Customer's gender (Male/Female)
# * SeniorCitizen: Whether the customer is a senior citizen (1: Yes, 0: No)
# * Partner: Whether the customer has a partner (Yes/No)
# * Dependents: Whether the customer has dependents (Yes/No)
# * tenure: Number of months the customer has stayed with the company
# * PhoneService, MultipleLines: Phone service subscription details
# * InternetService: Type of internet service (DSL, Fiber optic, No)
# * StreamingTV, StreamingMovies: Add-on service subscriptions
# * Contract: Type of contract (Month-to-month, One year, Two year)
# * PaperlessBilling: Whether the customer uses paperless billing (Yes/No)
# * PaymentMethod: How the customer pays (Electronic check, Mailed check, Bank transfer, Credit card)
# * MonthlyCharges: Amount charged to the customer monthly
# * TotalCharges: Total amount charged to the customer over their tenure
# * Churn: Whether the customer left the company (Yes/No)
#
# Source: https://www.kaggle.com/datasets/blastchar/telco-customer-churn

# %% [markdown]
# 1. **Load and Inspect** (2 points)
#    1. Load the dataset
#    2. Check `shape`
#    3. Check `info()`
#    4. Check `describe()`
#    5. Identify any dtype issues (hint: look closely at `TotalCharges`)

# %%
# Your Code Here

# %% [markdown]
# 2. **Data Cleaning** (5 points)
#    1. Check for missing values
#    2. Check for duplicate rows
#    3. Handle the `TotalCharges` dtype issue (blank strings → numeric)
#    4. Drop duplicate rows (if any)

# %%
# Your Code Here

# %% [markdown]
# 3. **Encoding** (5 points)
#    1. Perform label encoding for any two variables.
#    2. Perform one-hot encoding for any two variables.
#    3. Explain in 1–2 sentences why label encoding fits some columns and one-hot fits others

# %%
# Your Code Here

# %% [markdown]
# 4. **Binning** (3 points)
#    1. Bin `tenure` into categories of your choice (e.g., "New," "Established," "Long-term")
#    2. Justify your bin edges in 1–2 sentences

# %%
# Your Code Here

# %% [markdown]
# 5. **Univariate Analysis** (5 points)
#    1. Plot the distribution of at least three variables.
#    2. Plot a boxplot for each to check for outliers
#    3. Describe what you observe (skew, outliers, etc.)

# %%
# Your Code Here

# %% [markdown]
# 6. **Bivariate Analysis** (5 points)
#    1. Create a correlation heatmap of the numeric columns (`tenure`, `MonthlyCharges`, `TotalCharges`, and your encoded columns)
#    2. Identify which pairs are most strongly related
#    3. Visualize `Churn` against `Contract` type or `tenure` (boxplot or countplot)

# %%
# Your Code Here

# %% [markdown]
# 7. **Explore any additional relationship of your choice.** Explain what pattern you observe and why it might occur (5 points)

# %%
# Your Code Here
